# %% [markdown]
# # exploring the data

# %%
data <- read.csv("../Data/sperformance-dataset.csv", na.strings=c("na"," ","",".","NA"), header = TRUE)

# %%
head(data)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel.p
# 1 GP     F   15  R       GT3     T       1    1    at_home  other    ⋯ 3
# 2 GP     F   15  R       GT3     T       1    1    other    other    ⋯ 3
# 3 GP     F   15  R       GT3     T       2    2    at_home  other    ⋯ 4
# 4 GP     F   15  R       GT3     T       2    4    services health   ⋯ 4
# 5 GP     F   15  R       GT3     T       3    3    services services ⋯ 4
# 6 GP     F   15  R       GT3     T       3    4    services health   ⋯ 4
#   freetime.p goout.p Dalc.p Walc.p health.p absences.p pG1 pG2 pG3
# 1 1          2       1      1      1        4          13  13  13
# 2 3          4       2      4      5        2          13  11  11
# 3 3          1       1      1      2        8          14  13  12
# 4 3          2       1      1      5        2          10  11  10
# 5 2          1       2      3      3        2          13  13  13
# ...

# %%
summary(data)
# Out:
#  school   sex          age        address famsize   Pstatus      Medu
#  GP:342   F:198   Min.   :15.00   R: 81   GT3:278   A: 38   Min.   :0.000
#  MS: 40   M:184   1st Qu.:16.00   U:301   LE3:104   T:344   1st Qu.:2.000
#                   Median :17.00                             Median :3.000
#                   Mean   :16.59                             Mean   :2.806
#                   3rd Qu.:17.00                             3rd Qu.:4.000
#                   Max.   :22.00                             Max.   :4.000
#       Fedu             Mjob           Fjob            reason    nursery
#  Min.   :0.000   at_home : 53   at_home : 16   course    :140   no : 72
#  1st Qu.:2.000   health  : 33   health  : 17   home      :110   yes:310
#  Median :3.000   other   :138   other   :211   other     : 34
#  Mean   :2.565   services: 96   services:107   reputation: 98
#  3rd Qu.:4.000   teacher : 62   teacher : 31
#  Max.   :4.000
# ...

# %%
data
# Out:
#     school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯
# 1   GP     F   15  R       GT3     T       1    1    at_home  other    ⋯
# 2   GP     F   15  R       GT3     T       1    1    other    other    ⋯
# 3   GP     F   15  R       GT3     T       2    2    at_home  other    ⋯
# 4   GP     F   15  R       GT3     T       2    4    services health   ⋯
# 5   GP     F   15  R       GT3     T       3    3    services services ⋯
# 6   GP     F   15  R       GT3     T       3    4    services health   ⋯
# 7   GP     F   15  R       GT3     T       3    4    services teacher  ⋯
# 8   GP     F   15  R       LE3     T       2    2    health   services ⋯
# 9   GP     F   15  R       LE3     T       3    1    other    other    ⋯
# 10  GP     F   15  U       GT3     A       3    3    other    health   ⋯
# 11  GP     F   15  U       GT3     A       4    3    services services ⋯
# 12  GP     F   15  U       GT3     T       1    1    at_home  other    ⋯
# ...
