# %% [markdown]
# # Explore and Analyse

# %%
library(e1071)   
library(psych)
library(tidyverse)
library(ggplot2)
library(gridExtra)
library(cowplot)
library(sqldf)
# Out:
# Loading required package: gsubfn
#
# Loading required package: proto
#
# Loading required package: RSQLite

# %%
data <- read.csv("../Data/sperformance-dataset.csv", na.strings=c("na"," ","",".","NA"), header = TRUE)

# %%
hyp1_score_data <- sqldf("select mg1,mg2,mg3,pg1,pg2,pg3 from data")

# %%
# Better form of summary statisitcs in R usinf the psych library
describe(hyp1_score_data)
# Out:
#     vars n   mean     sd       median trimmed  mad    min max range skew
# mG1 1    382 10.86126 3.349167 10.5   10.74510 3.7065 3   19  16     0.2741912
# mG2 2    382 10.71204 3.832560 11.0   10.83007 2.9652 0   19  19    -0.3970490
# mG3 3    382 10.38743 4.687242 11.0   10.81373 4.4478 0   20  20    -0.7003219
# pG1 4    382 12.11257 2.556531 12.0   12.09150 2.9652 0   19  19    -0.1523548
# pG2 5    382 12.23822 2.468341 12.0   12.15359 2.9652 5   19  14     0.2368869
# pG3 6    382 12.51571 2.945438 13.0   12.62092 2.9652 0   19  19    -0.9891237
#     kurtosis   se
# mG1 -0.7061137 0.1713583
# mG2  0.4666241 0.1960908
# mG3  0.2415275 0.2398202
# pG1  0.6986985 0.1308035
# pG2 -0.2038155 0.1262913
# pG3  3.3902597 0.1507017

# %%
plot_list <- list()
for(i in colnames(hyp1_score_data)){
    print(mean(hyp1_score_data[,i]))
    gg <- ggplot(hyp1_score_data , aes_string(i))  
    gg <- gg + geom_histogram(binwidth=1, colour="black", aes(y=..density.., fill=..count..))
    gg<-gg+scale_fill_gradient("Count", low="#DCDCDC", high="#7C7C7C")
    gg<-gg+stat_function(fun=dnorm, color="red",args=list(mean=mean(hyp1_score_data[,i], na.rm=TRUE), sd=sd(hyp1_score_data[,i], na.rm=TRUE)))
    plot_list[[i]] <- gg
} # end of loop
# Out:
# [1] 10.86126
# [1] 10.71204
# [1] 10.38743
# [1] 12.11257
# [1] 12.23822
# [1] 12.51571

# %%
options(repr.plot.width = 16, repr.plot.height = 10)
plot_grid(plotlist = plot_list)
# Out:
# plot without title

# %%
# qq plot
qqnorm(hyp1_score_data$mG1 ,main='mG1')+qqline(hyp1_score_data$mG1, col=2) #show a line on theplot
# Out:
# Error in qqnorm(hyp1_score_data$mG1, main = "mG1") + qqline(hyp1_score_data$mG1, : non-numeric argument to binary operator
# Traceback:
# Plot with title “mG1”

# %%
qqnorm(hyp1_score_data$mG2,main='mG2')+qqline(hyp1_score_data$mG2, col=2)
# Out:
# Error in qqnorm(hyp1_score_data$mG2) + qqline(hyp1_score_data$mG2, col = 2): non-numeric argument to binary operator
# Traceback:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(hyp1_score_data$mG3,main='mG3')+qqline(hyp1_score_data$mG3, col=2)
# Out:
# Error in qqnorm(hyp1_score_data$mG3) + qqline(hyp1_score_data$mG3, col = 2): non-numeric argument to binary operator
# Traceback:
# Plot with title “Normal Q-Q Plot”
